# %%
for i in range(1,10):
    for j in range(1, 10):
        for k in range(1, 10):
            print(str(i) + "x" + str(j) + "x" + str(k) + "=" + str(i*j*k))
# Out:
# 1x1x1=1
# 1x1x2=2
# 1x1x3=3
# 1x1x4=4
# 1x1x5=5
# 1x1x6=6
# 1x1x7=7
# 1x1x8=8
# 1x1x9=9
# 1x2x1=2
# 1x2x2=4
# 1x2x3=6
# 1x2x4=8
# 1x2x5=10
# 1x2x6=12
# 1x2x7=14
# 1x2x8=16
# 1x2x9=18
# 1x3x1=3
# 1x3x2=6
# 1x3x3=9
# 1x3x4=12
# 1x3x5=15
# 1x3x6=18
# 1x3x7=21
# 1x3x8=24
# 1x3x9=27
# 1x4x1=4
# 1x4x2=8
# 1x4x3=12
# 1x4x4=16
# 1x4x5=20
# 1x4x6=24
# 1x4x7=28
# 1x4x8=32
# 1x4x9=36
# 1x5x1=5
# 1x5x2=10
# 1x5x3=15
# 1x5x4=20
# 1x5x5=25
# 1x5x6=30
# 1x5x7=35
# 1x5x8=40
# 1x5x9=45
# 1x6x1=6
# 1x6x2=12
# 1x6x3=18
# 1x6x4=24
# 1x6x5=30
# 1x6x6=36
# 1x6x7=42
# 1x6x8=48
# 1x6x9=54
# 1x7x1=7
# 1x7x2=14
# 1x7x3=21
# 1x7x4=28
# 1x7x5=35
# 1x7x6=42
# 1x7x7=49
# 1x7x8=56
# 1x7x9=63
# 1x8x1=8
# 1x8x2=16
# 1x8x3=24
# 1x8x4=32
# 1x8x5=40
# 1x8x6=48
# 1x8x7=56
# 1x8x8=64
# 1x8x9=72
# 1x9x1=9
# 1x9x2=18
# 1x9x3=27
# 1x9x4=36
# 1x9x5=45
# 1x9x6=54
# 1x9x7=63
# 1x9x8=72
# 1x9x9=81
# 2x1x1=2
# 2x1x2=4
# 2x1x3=6
# 2x1x4=8
# 2x1x5=10
# 2x1x6=12
# 2x1x7=14
# 2x1x8=16
# 2x1x9=18
# 2x2x1=4
# 2x2x2=8
# 2x2x3=12
# ...
