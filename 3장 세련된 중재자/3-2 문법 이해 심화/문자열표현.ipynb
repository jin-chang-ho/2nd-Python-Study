# %%
학생1 = input("학생 1의 이름: ")
학생2 = input("학생 2의 이름: ")
print("%s🖤%s" % (학생1[1:], 학생2[1:]))
# Out:
# 학생 1의 이름: 김철수
# 학생 2의 이름: 박영희
# 철수🖤영희

# %%
multiply = int(input("몇 단?: "))
for i in range(1, 10):
    print("%d x %d = %d" % (multiply, i, multiply * i))
# Out:
# 몇 단?: 8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
